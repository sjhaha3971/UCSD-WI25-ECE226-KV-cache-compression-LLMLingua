# %%
#!pip install transformers==4.41.2

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.41.2

# %%
import os
import json
import time
import torch
import numpy as np
from transformers import AutoTokenizer, AutoModel
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
tokenizer = AutoTokenizer.from_pretrained("THUDM/chatglm2-6b-32k", trust_remote_code=True)
model = AutoModel.from_pretrained("THUDM/chatglm2-6b-32k", trust_remote_code=True, torch_dtype=torch.float16).to(device)
model = model.eval()
# Monkey-patch the tokenizer's _pad method to handle the padding_side argument
original_pad = tokenizer._pad
def new_pad(self, encoded_inputs, max_length=None, padding_strategy="longest", pad_to_multiple_of=None, return_attention_mask=None, **kwargs):
    return original_pad(encoded_inputs, max_length, padding_strategy, pad_to_multiple_of, return_attention_mask)
tokenizer._pad = new_pad.__get__(tokenizer, type(tokenizer))
# Out:
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
import re
import string
from collections import Counter
def normalize_answer(s):
    """Lower text and remove punctuation, articles and extra whitespace."""

    def remove_articles(text):
        return re.sub(r"\b(a|an|the)\b", " ", text)

    def white_space_fix(text):
        return " ".join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return "".join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))

def f1_score(prediction, ground_truth):
    common = Counter(prediction) & Counter(ground_truth)
    num_same = sum(common.values())
    if num_same == 0:
        return 0
    precision = 1.0 * num_same / len(prediction)
    recall = 1.0 * num_same / len(ground_truth)
    f1 = (2 * precision * recall) / (precision + recall)
    return f1

def qa_f1_score(prediction, ground_truth):
    normalized_prediction = normalize_answer(prediction)
    normalized_ground_truth = normalize_answer(ground_truth)

    prediction_tokens = normalized_prediction.split()
    ground_truth_tokens = normalized_ground_truth.split()
    return f1_score(prediction_tokens, ground_truth_tokens)

# %%
def evaluate_multifield(df):
  metrics = {'_id':[], 'f1_scores':[], 'latencies':[], 'memory_usages':[], 'peak_memory_usages':[], 'responses':[]}

  for index, row in df.iterrows():
    print(f"Processing {index}")
    try:
      metrics["_id"].append(row["_id"])
      prompt = "Read the following text and answer briefly.\n\n{context}\n\nNow, answer the following question based on the above text, only give me the answer and do not output any other words.\n\nQuestion: {input}\nAnswer:".format(context=row['summary'], input=row['input'])
      torch.cuda.reset_peak_memory_stats()
      start_time = time.time()
      response, _ = model.chat(tokenizer, prompt)
      metrics["responses"].append(response)
      total_time = time.time() - start_time
      print(f"Time taken {total_time}")

      metrics["latencies"].append(total_time)

      # Measure memory
      memory = torch.cuda.memory_allocated() / (1024 ** 2)  # MB

      #Measure peak memory
      peak_memory = torch.cuda.max_memory_allocated() / (1024 ** 2)
      metrics["memory_usages"].append(memory)
      metrics["peak_memory_usages"].append(peak_memory)
      metrics["f1_scores"].append(qa_f1_score(response, row['answers'][0]))

    except Exception as e:
      print("Failed with error: ", e)
      metrics["_id"].append(row["_id"])
      metrics["responses"].append(None)
      metrics["latencies"].append(None)
      metrics["memory_usages"].append(None)
      metrics["peak_memory_usages"].append(None)
      metrics["f1_scores"].append(None)
  return metrics

# %%
def evaluate_hotpot(df):
  metrics = {'_id':[], 'f1_scores':[], 'latencies':[], 'memory_usages':[], 'peak_memory_usages':[], 'responses':[]}

  for index, row in df.iterrows():
    print(f"Processing {index}")
    try:
      metrics["_id"].append(row["_id"])
      prompt = "Answer the question based on the given passages. Only give me the answer and do not output any other words.\n\nThe following are given passages.\n{context}\n\nAnswer the question based on the given passages. Only give me the answer and do not output any other words.\n\nQuestion: {input}\nAnswer:".format(context=row['summary'], input=row['input'])
      torch.cuda.reset_peak_memory_stats()
      start_time = time.time()
      response, _ = model.chat(tokenizer, prompt)
      metrics["responses"].append(response)
      total_time = time.time() - start_time
      print(f"Time taken {total_time}")

      metrics["latencies"].append(total_time)

      # Measure memory
      memory = torch.cuda.memory_allocated() / (1024 ** 2)  # MB

      #Measure peak memory
      peak_memory = torch.cuda.max_memory_allocated() / (1024 ** 2)
      metrics["memory_usages"].append(memory)
      metrics["peak_memory_usages"].append(peak_memory)
      metrics["f1_scores"].append(qa_f1_score(response, row['answers'][0]))

    except Exception as e:
      print("Failed with error: ", e)
      metrics["_id"].append(row["_id"])
      metrics["responses"].append(None)
      metrics["latencies"].append(None)
      metrics["memory_usages"].append(None)
      metrics["peak_memory_usages"].append(None)
      metrics["f1_scores"].append(None)
  return metrics

# %%
def evaluate_trivia(df):
  metrics = {'_id':[], 'f1_scores':[], 'latencies':[], 'memory_usages':[], 'peak_memory_usages':[], 'responses':[]}

  for index, row in df.iterrows():
    print(f"Processing {index}")
    try:
      metrics["_id"].append(row["_id"])
      prompt = "Answer the question based on the given passage. Only give me the answer and do not output any other words. The following are some examples.\n\n{context}\n\n{input}".format(context=row['summary'], input=row['input'])
      torch.cuda.reset_peak_memory_stats()
      start_time = time.time()
      response, _ = model.chat(tokenizer, prompt)
      metrics["responses"].append(response)
      total_time = time.time() - start_time
      print(f"Time taken {total_time}")

      metrics["latencies"].append(total_time)

      # Measure memory
      memory = torch.cuda.memory_allocated() / (1024 ** 2)  # MB

      #Measure peak memory
      peak_memory = torch.cuda.max_memory_allocated() / (1024 ** 2)
      metrics["memory_usages"].append(memory)
      metrics["peak_memory_usages"].append(peak_memory)
      metrics["f1_scores"].append(qa_f1_score(response, row['answers'][0]))

    except Exception as e:
      print("Failed with error: ", e)
      metrics["_id"].append(row["_id"])
      metrics["responses"].append(None)
      metrics["latencies"].append(None)
      metrics["memory_usages"].append(None)
      metrics["peak_memory_usages"].append(None)
      metrics["f1_scores"].append(None)
  return metrics

# %%
def evaluate_narrative(df):
  metrics = {'_id':[], 'f1_scores':[], 'latencies':[], 'memory_usages':[], 'peak_memory_usages':[], 'responses':[]}

  for index, row in df.iterrows():
    print(f"Processing {index}")
    try:
      metrics["_id"].append(row["_id"])
      prompt = "You are given a story, which can be either a novel or a movie script, and a question. Answer the question asconcisely as you can, using a single phrase if possible. Do not provide any explanation.\n\nStory: {context}\n\nNow, answer the question based on the story asconcisely as you can, using a single phrase if possible. Do not provide any explanation.\n\nQuestion: {input}\n\nAnswer:".format(context=row['summary'], input=row['input'])
      torch.cuda.reset_peak_memory_stats()
      start_time = time.time()
      response, _ = model.chat(tokenizer, prompt)
      metrics["responses"].append(response)
      total_time = time.time() - start_time
      print(f"Time taken {total_time}")

      metrics["latencies"].append(total_time)

      # Measure memory
      memory = torch.cuda.memory_allocated() / (1024 ** 2)  # MB

      #Measure peak memory
      peak_memory = torch.cuda.max_memory_allocated() / (1024 ** 2)
      metrics["memory_usages"].append(memory)
      metrics["peak_memory_usages"].append(peak_memory)
      metrics["f1_scores"].append(qa_f1_score(response, row['answers'][0]))

    except Exception as e:
      print("Failed with error: ", e)
      metrics["_id"].append(row["_id"])
      metrics["responses"].append(None)
      metrics["latencies"].append(None)
      metrics["memory_usages"].append(None)
      metrics["peak_memory_usages"].append(None)
      metrics["f1_scores"].append(None)
  return metrics

# %%
dataset_name_list = ['multifieldqa', 'hotpotqa', 'triviaqa', 'narrativeqa']

# %%
import pandas as pd
import json
import torch
import time

ratios = [0.25, 0.5, 0.75]
# dataset_name_list = ['hotpotqa', 'narrative_qa', 'triviaqa', 'multifieldqa']
dataset_name = dataset_name_list[0]  #multifieldqa
for i in ratios:
    try:
      df = pd.read_csv(f'{dataset_name}/summarize_{dataset_name}_{int(i * 100)}.csv')
      metrics = evaluate_multifield(df)
      with open(f'{dataset_name}_metrics_{int(i * 100)}.json', 'w') as f:
        json.dump(metrics, f)
    except Exception as e:
        print("Failed with error: ", e)
# Out:
# Processing 0
# Time taken 1.4531891345977783
# Processing 1
# Time taken 0.8736612796783447
# Processing 2
# Time taken 1.2118747234344482
# Processing 3
# Time taken 1.1313531398773193
# Processing 4
# Time taken 1.3239362239837646
# Processing 5
# Time taken 1.1014785766601562
# Processing 6
# Time taken 0.5796425342559814
# Processing 7
# Time taken 0.18744754791259766
# Processing 8
# Time taken 0.29257988929748535
# Processing 9
# Time taken 0.7246441841125488
# Processing 10
# Time taken 1.2328569889068604
# Processing 11
# Time taken 0.4434385299682617
# Processing 12
# Time taken 0.6720201969146729
# Processing 13
# Time taken 0.633056640625
# Processing 14
# Time taken 0.8250296115875244
# Processing 15
# Time taken 0.24315404891967773
# Processing 16
# Time taken 0.38458871841430664
# Processing 17
# Time taken 1.0456411838531494
# Processing 18
# Time taken 0.5807092189788818
# Processing 19
# Time taken 0.2324965000152588
# Processing 20
# Time taken 0.2625463008880615
# Processing 21
# Time taken 0.47435498237609863
# Processing 22
# Time taken 0.9555585384368896
# Processing 23
# Time taken 0.4888920783996582
# Processing 24
# Time taken 1.068408489227295
# Processing 25
# Time taken 0.5114808082580566
# Processing 26
# Time taken 0.852910041809082
# Processing 27
# Time taken 0.9126379489898682
# Processing 28
# Time taken 0.9451320171356201
# Processing 29
# Time taken 0.5875918865203857
# Processing 30
# Time taken 0.5894308090209961
# Processing 31
# Time taken 0.6963915824890137
# Processing 32
# Time taken 0.8718357086181641
# Processing 33
# Time taken 0.6308002471923828
# Processing 34
# Time taken 0.8033483028411865
# Processing 35
# Time taken 0.5033831596374512
# Processing 36
# Time taken 0.11401939392089844
# Processing 37
# Time taken 0.46333789825439453
# Processing 38
# Time taken 0.43407368659973145
# Processing 39
# Time taken 0.2402820587158203
# Processing 40
# Time taken 0.31114792823791504
# Processing 41
# Time taken 0.20867013931274414
# Processing 42
# Time taken 0.5962355136871338
# Processing 43
# Time taken 0.7485895156860352
# Processing 44
# Time taken 0.5280749797821045
# Processing 45
# Time taken 2.659456253051758
# Processing 46
# Time taken 0.4039337635040283
# Processing 47
# Time taken 0.8745541572570801
# Processing 48
# Time taken 0.2614314556121826
# Processing 49
# Time taken 0.23790502548217773
# Processing 50
# Time taken 0.3391547203063965
# Processing 51
# Time taken 1.3156743049621582
# Processing 52
# Time taken 1.197265625
# Processing 53
# Time taken 0.2491922378540039
# Processing 54
# Time taken 0.30946826934814453
# Processing 55
# Time taken 0.22038841247558594
# Processing 56
# Time taken 0.333202600479126
# Processing 57
# Time taken 0.3401787281036377
# Processing 58
# Time taken 1.3621821403503418
# Processing 59
# Time taken 0.30758190155029297
# Processing 60
# Time taken 0.9503860473632812
# Processing 61
# Time taken 1.3271064758300781
# Processing 62
# Time taken 0.36339640617370605
# Processing 63
# Time taken 0.1911332607269287
# Processing 64
# Time taken 0.6448664665222168
# Processing 65
# Time taken 0.774674654006958
# Processing 66
# Time taken 0.4794766902923584
# Processing 67
# Time taken 1.4682867527008057
# Processing 68
# Time taken 0.3226475715637207
# Processing 69
# Time taken 0.7007725238800049
# Processing 70
# Time taken 0.21012306213378906
# Processing 71
# Time taken 0.12633204460144043
# Processing 72
# Time taken 3.5111119747161865
# Processing 73
# Time taken 0.7377886772155762
# Processing 74
# Time taken 0.6812434196472168
# Processing 75
# Time taken 0.7069075107574463
# Processing 76
# Time taken 0.28741025924682617
# Processing 77
# Time taken 0.7698471546173096
# Processing 78
# Time taken 0.5563561916351318
# Processing 79
# Time taken 0.7891867160797119
# Processing 80
# Time taken 0.4872779846191406
# Processing 81
# Time taken 0.49190568923950195
# Processing 82
# Time taken 0.6373553276062012
# Processing 83
# Time taken 0.16146206855773926
# Processing 84
# Time taken 1.0240545272827148
# Processing 85
# Time taken 1.2491858005523682
# Processing 86
# Time taken 0.20769953727722168
# Processing 87
# Time taken 0.19780683517456055
# Processing 88
# Time taken 0.6783721446990967
# Processing 89
# Time taken 0.2771487236022949
# Processing 90
# Time taken 0.6391985416412354
# Processing 91
# Time taken 0.7491030693054199
# Processing 92
# Time taken 1.272766351699829
# Processing 93
# Time taken 0.620542049407959
# Processing 94
# Time taken 1.1634588241577148
# Processing 95
# Time taken 0.4209940433502197
# Processing 96
# Time taken 0.3891453742980957
# Processing 97
# Time taken 0.7213163375854492
# Processing 98
# Time taken 0.5876929759979248
# Processing 99
# Time taken 0.6381397247314453
# Processing 0
# Time taken 0.26377272605895996
# Processing 1
# Time taken 1.5418920516967773
# Processing 2
# Time taken 1.4605250358581543
# Processing 3
# Time taken 1.3529787063598633
# Processing 4
# Time taken 1.7740540504455566
# Processing 5
# Time taken 1.7219445705413818
# Processing 6
# Time taken 1.3213367462158203
# Processing 7
# Time taken 0.30611562728881836
# Processing 8
# Time taken 0.36180877685546875
# Processing 9
# Time taken 1.552013635635376
# Processing 10
# Time taken 1.8649888038635254
# Processing 11
# Time taken 1.0947813987731934
# Processing 12
# Time taken 1.5910184383392334
# Processing 13
# Time taken 0.7386488914489746
# Processing 14
# Time taken 1.6690647602081299
# Processing 15
# Time taken 0.37268900871276855
# Processing 16
# Time taken 0.8189835548400879
# Processing 17
# Time taken 1.3380343914031982
# Processing 18
# Time taken 1.052351951599121
# Processing 19
# Time taken 0.38867807388305664
# Processing 20
# Time taken 0.873199462890625
# Processing 21
# Time taken 1.1514408588409424
# Processing 22
# Time taken 0.7128703594207764
# Processing 23
# Time taken 1.175715446472168
# Processing 24
# Time taken 0.7207868099212646
# Processing 25
# Time taken 1.3154711723327637
# Processing 26
# Time taken 2.7290239334106445
# Processing 27
# Time taken 1.437610387802124
# Processing 28
# Time taken 1.0101819038391113
# Processing 29
# Time taken 1.1088604927062988
# Processing 30
# Time taken 0.8104698657989502
# Processing 31
# Time taken 1.266510009765625
# Processing 32
# Time taken 0.9164752960205078
# Processing 33
# Time taken 1.435420036315918
# Processing 34
# Time taken 0.6834235191345215
# Processing 35
# Time taken 0.18720173835754395
# Processing 36
# Time taken 0.8559565544128418
# Processing 37
# Time taken 0.48636674880981445
# Processing 38
# Time taken 0.3938872814178467
# Processing 39
# Time taken 0.4465341567993164
# Processing 40
# Time taken 0.29588747024536133
# Processing 41
# Time taken 0.710742712020874
# Processing 42
# Time taken 1.2609283924102783
# Processing 43
# Time taken 0.9514389038085938
# Processing 44
# Time taken 1.8596246242523193
# Processing 45
# Time taken 0.6705925464630127
# Processing 46
# Time taken 1.9178085327148438
# Processing 47
# Time taken 0.41002535820007324
# Processing 48
# Time taken 0.33791208267211914
# Processing 49
# Time taken 0.4684302806854248
# Processing 50
# Time taken 1.8936707973480225
# Processing 51
# Time taken 1.5704855918884277
# Processing 52
# Time taken 0.43969273567199707
# Processing 53
# Time taken 0.4546232223510742
# Processing 54
# Time taken 0.3231978416442871
# Processing 55
# Time taken 0.499194860458374
# Processing 56
# Time taken 0.46863222122192383
# Processing 57
# Time taken 1.2788958549499512
# Processing 58
# Time taken 0.4365692138671875
# Processing 59
# Time taken 1.903184413909912
# Processing 60
# Time taken 1.3715388774871826
# Processing 61
# Time taken 0.49220919609069824
# Processing 62
# Time taken 0.326873779296875
# Processing 63
# Time taken 0.6137874126434326
# Processing 64
# Time taken 1.3932688236236572
# Processing 65
# Time taken 0.9325852394104004
# Processing 66
# Time taken 1.243194818496704
# Processing 67
# Time taken 0.6356410980224609
# Processing 68
# Time taken 0.8684308528900146
# Processing 69
# Time taken 0.2969956398010254
# Processing 70
# Time taken 0.1724402904510498
# Processing 71
# Time taken 1.4917206764221191
# Processing 72
# Time taken 1.016650915145874
# Processing 73
# Time taken 1.313354730606079
# Processing 74
# Time taken 1.5632636547088623
# Processing 75
# Time taken 0.3820381164550781
# Processing 76
# Time taken 1.0111231803894043
# Processing 77
# Time taken 0.7916989326477051
# Processing 78
# Time taken 1.1355464458465576
# Processing 79
# Time taken 0.8608283996582031
# Processing 80
# Time taken 0.824655294418335
# Processing 81
# Time taken 0.7944736480712891
# Processing 82
# Time taken 0.20907115936279297
# Processing 83
# Time taken 1.7693946361541748
# Processing 84
# Time taken 1.6898725032806396
# Processing 85
# Time taken 0.3859379291534424
# Processing 86
# Time taken 0.39649486541748047
# Processing 87
# Time taken 0.9113337993621826
# Processing 88
# Time taken 0.5520164966583252
# Processing 89
# Time taken 1.1991384029388428
# Processing 90
# Time taken 1.427417278289795
# Processing 91
# Time taken 1.5509510040283203
# Processing 92
# Time taken 0.7858307361602783
# Processing 93
# Time taken 1.9811010360717773
# Processing 94
# Time taken 1.5846681594848633
# Processing 95
# Time taken 0.4263284206390381
# Processing 96
# Time taken 1.2219486236572266
# Processing 97
# Time taken 1.1235456466674805
# Processing 98
# Time taken 1.2666761875152588
# Processing 99
# Time taken 1.27522873878479
# Processing 100
# Time taken 0.3732008934020996
# Processing 101
# Time taken 1.2914116382598877
# Processing 102
# Time taken 0.848454475402832
# Processing 103
# Time taken 1.2030174732208252
# Processing 104
# Time taken 0.543248176574707
# Processing 105
# Time taken 1.5844128131866455
# Processing 106
# Time taken 0.871959924697876
# Processing 107
# Time taken 0.896735668182373
# Processing 108
# Time taken 1.075713872909546
# Processing 109
# Time taken 0.9733238220214844
# Processing 110
# Time taken 1.287222146987915
# Processing 111
# Time taken 2.230309009552002
# Processing 112
# Time taken 0.3385050296783447
# Processing 113
# Time taken 0.812387228012085
# Processing 114
# Time taken 1.0633797645568848
# Processing 115
# Time taken 1.0688087940216064
# Processing 116
# Time taken 0.9312136173248291
# Processing 117
# Time taken 1.930049180984497
# Processing 118
# Time taken 1.4932808876037598
# Processing 119
# Time taken 0.8442296981811523
# Processing 120
# Time taken 0.9206457138061523
# Processing 121
# Time taken 0.49260997772216797
# Processing 122
# Time taken 0.7204091548919678
# Processing 123
# Time taken 0.4050414562225342
# Processing 124
# Time taken 0.592106819152832
# Processing 125
# Time taken 1.403376579284668
# Processing 126
# Time taken 1.087609052658081
# Processing 127
# Time taken 1.1565144062042236
# Processing 128
# Time taken 1.0123543739318848
# Processing 129
# Time taken 0.5321712493896484
# Processing 130
# Time taken 0.9887022972106934
# Processing 131
# Time taken 0.4034910202026367
# Processing 132
# Time taken 0.40293407440185547
# Processing 133
# Time taken 14.88103985786438
# Processing 134
# Time taken 1.2608628273010254
# Processing 135
# Time taken 1.2071499824523926
# Processing 136
# Time taken 1.4381608963012695
# Processing 137
# Time taken 0.8243451118469238
# Processing 138
# Time taken 0.9877207279205322
# Processing 139
# Time taken 1.3730499744415283
# Processing 140
# Time taken 1.3133420944213867
# Processing 141
# Time taken 0.5515406131744385
# Processing 142
# Time taken 0.45411205291748047
# Processing 143
# Time taken 1.665569543838501
# Processing 144
# Time taken 0.7327184677124023
# Processing 145
# Time taken 0.48286938667297363
# Processing 146
# Time taken 1.484910249710083
# Processing 147
# Time taken 0.39800190925598145
# Processing 148
# Time taken 0.7456393241882324
# Processing 149
# Time taken 0.9733767509460449
# Processing 150
# Time taken 1.1020102500915527
# Processing 0
# Time taken 0.3272833824157715
# Processing 1
# Time taken 2.2863285541534424
# Processing 2
# Time taken 1.9131393432617188
# Processing 3
# Time taken 2.298327922821045
# Processing 4
# Time taken 2.224682569503784
# Processing 5
# Time taken 1.8516578674316406
# Processing 6
# Time taken 1.5357708930969238
# Processing 7
# Time taken 0.42363810539245605
# Processing 8
# Time taken 0.4244518280029297
# Processing 9
# Time taken 1.740687370300293
# Processing 10
# Time taken 2.017249584197998
# Processing 11
# Time taken 1.5260803699493408
# Processing 12
# Time taken 2.235191822052002
# Processing 13
# Time taken 1.0524723529815674
# Processing 14
# Time taken 1.456240177154541
# Processing 15
# Time taken 0.48027849197387695
# Processing 16
# Time taken 1.590041160583496
# Processing 17
# Time taken 1.615729808807373
# Processing 18
# Time taken 1.5067541599273682
# Processing 19
# Time taken 0.5480554103851318
# Processing 20
# Time taken 0.4530820846557617
# Processing 21
# Time taken 1.4114816188812256
# Processing 22
# Time taken 3.6712958812713623
# Processing 23
# Time taken 0.9507579803466797
# Processing 24
# Time taken 2.1907052993774414
# Processing 25
# Time taken 1.1040422916412354
# Processing 26
# Time taken 1.7879362106323242
# Processing 27
# Time taken 6.913084506988525
# Processing 28
# Time taken 1.5520503520965576
# Processing 29
# Time taken 1.566784381866455
# Processing 30
# Time taken 0.6911230087280273
# Processing 31
# Time taken 1.350417137145996
# Processing 32
# Time taken 1.6396732330322266
# Processing 33
# Time taken 0.8566911220550537
# Processing 34
# Time taken 1.7564020156860352
# Processing 35
# Time taken 1.1932320594787598
# Processing 36
# Time taken 0.48548007011413574
# Processing 37
# Time taken 1.2585644721984863
# Processing 38
# Time taken 0.7257800102233887
# Processing 39
# Time taken 0.5471243858337402
# Processing 40
# Time taken 0.6448590755462646
# Processing 41
# Time taken 0.3833651542663574
# Processing 42
# Time taken 0.9795615673065186
# Processing 43
# Time taken 1.7661190032958984
# Processing 44
# Time taken 1.3426766395568848
# Processing 45
# Time taken 1.7157204151153564
# Processing 46
# Time taken 0.9222579002380371
# Processing 47
# Time taken 1.6477808952331543
# Processing 48
# Time taken 0.5343754291534424
# Processing 49
# Time taken 0.38837170600891113
# Processing 50
# Time taken 0.47995996475219727
# Processing 51
# Time taken 2.4596245288848877
# Processing 52
# Time taken 2.025928020477295
# Processing 53
# Time taken 0.6499426364898682
# Processing 54
# Time taken 0.5563993453979492
# Processing 55
# Time taken 0.40534496307373047
# Processing 56
# Time taken 0.7391049861907959
# Processing 57
# Time taken 0.5935845375061035
# Processing 58
# Time taken 0.8325345516204834
# Processing 59
# Time taken 0.585263729095459
# Processing 60
# Time taken 2.3479487895965576
# Processing 61
# Time taken 1.9444966316223145
# Processing 62
# Time taken 0.6208996772766113
# Processing 63
# Time taken 0.46297121047973633
# Processing 64
# Time taken 0.551260232925415
# Processing 65
# Time taken 1.742884874343872
# Processing 66
# Time taken 1.4646241664886475
# Processing 67
# Time taken 2.5219383239746094
# Processing 68
# Time taken 0.8186051845550537
# Processing 69
# Time taken 5.200403928756714
# Processing 70
# Time taken 0.3884134292602539
# Processing 71
# Time taken 0.6701018810272217
# Processing 72
# Time taken 1.7181477546691895
# Processing 73
# Time taken 1.405547857284546
# Processing 74
# Time taken 1.9239628314971924
# Processing 75
# Time taken 2.0521059036254883
# Processing 76
# Time taken 0.4791748523712158
# Processing 77
# Time taken 1.0699748992919922
# Processing 78
# Time taken 1.1352324485778809
# Processing 79
# Time taken 1.0271053314208984
# Processing 80
# Time taken 1.2601892948150635
# Processing 81
# Time taken 1.1232781410217285
# Processing 82
# Time taken 0.9945535659790039
# Processing 83
# Time taken 0.27770304679870605
# Processing 84
# Time taken 2.242357015609741
# Processing 85
# Time taken 2.3290700912475586
# Processing 86
# Time taken 0.4530456066131592
# Processing 87
# Time taken 0.4788060188293457
# Processing 88
# Time taken 1.1772000789642334
# Processing 89
# Time taken 1.0180926322937012
# Processing 90
# Time taken 1.9305369853973389
# Processing 91
# Time taken 2.249972105026245
# Processing 92
# Time taken 1.8029778003692627
# Processing 93
# Time taken 0.9331676959991455
# Processing 94
# Time taken 2.7214934825897217
# Processing 95
# Time taken 2.3251349925994873
# Processing 96
# Time taken 0.7579505443572998
# Processing 97
# Time taken 1.741706371307373
# Processing 98
# Time taken 2.0960724353790283
# Processing 99
# Time taken 2.1086435317993164

# %%
import pandas as pd
import json
import torch
import time

ratios = [0.25, 0.5, 0.75]
# dataset_name_list = ['hotpotqa', 'narrative_qa', 'triviaqa', 'multifieldqa']
dataset_name = dataset_name_list[1]  #hotpotqa
for i in ratios:
    try:
      df = pd.read_csv(f'{dataset_name}/summarize_{dataset_name}_{int(i * 100)}.csv')
      metrics = evaluate_hotpot(df)
      with open(f'{dataset_name}_metrics_{int(i * 100)}.json', 'w') as f:
        json.dump(metrics, f)
    except Exception as e:
        print("Failed with error: ", e)
# Out:
# Processing 0
# Time taken 0.6511623859405518
# Processing 1
# Time taken 0.8640518188476562
# Processing 2
# Time taken 0.8670048713684082
# Processing 3
# Time taken 0.8105552196502686
# Processing 4
# Time taken 0.7205681800842285
# Processing 5
# Time taken 0.7838115692138672
# Processing 6
# Time taken 0.7894818782806396
# Processing 7
# Time taken 0.2238001823425293
# Processing 8
# Time taken 0.6705532073974609
# Processing 9
# Time taken 0.5024318695068359
# Processing 10
# Time taken 1.04695463180542
# Processing 11
# Time taken 0.818793773651123
# Processing 12
# Time taken 0.8221344947814941
# Processing 13
# Time taken 0.47844386100769043
# Processing 14
# Time taken 0.9917526245117188
# Processing 15
# Time taken 0.6893248558044434
# Processing 16
# Time taken 0.4423379898071289
# Processing 17
# Time taken 0.7803754806518555
# Processing 18
# Time taken 0.8340470790863037
# Processing 19
# Time taken 0.7686879634857178
# Processing 20
# Time taken 0.5914397239685059
# Processing 21
# Time taken 0.7937800884246826
# Processing 22
# Time taken 0.2827930450439453
# Processing 23
# Time taken 0.8766443729400635
# Processing 24
# Time taken 0.8619771003723145
# Processing 25
# Time taken 0.6465671062469482
# Processing 26
# Time taken 0.8242483139038086
# Processing 27
# Time taken 0.46404457092285156
# Processing 28
# Time taken 0.3424804210662842
# Processing 29
# Time taken 1.0398550033569336
# Processing 30
# Time taken 0.9413578510284424
# Processing 31
# Time taken 1.0449073314666748
# Processing 32
# Time taken 0.8808121681213379
# Processing 33
# Time taken 0.834458589553833
# Processing 34
# Time taken 0.6413545608520508
# Processing 35
# Time taken 0.9720430374145508
# Processing 36
# Time taken 0.7568838596343994
# Processing 37
# Time taken 0.6249096393585205
# Processing 38
# Time taken 1.6563408374786377
# Processing 39
# Time taken 0.9446208477020264
# Processing 40
# Time taken 0.9600815773010254
# Processing 41
# Time taken 0.8780462741851807
# Processing 42
# Time taken 0.7325763702392578
# Processing 43
# Time taken 0.741633415222168
# Processing 44
# Time taken 0.8790867328643799
# Processing 45
# Time taken 0.6860377788543701
# Processing 46
# Time taken 0.6265811920166016
# Processing 47
# Time taken 0.7069113254547119
# Processing 48
# Time taken 0.5127170085906982
# Processing 49
# Time taken 0.8409335613250732
# Processing 0
# Time taken 1.1528587341308594
# Processing 1
# Time taken 1.6452674865722656
# Processing 2
# Time taken 1.5332205295562744
# Processing 3
# Time taken 1.6387662887573242
# Processing 4
# Time taken 1.376176357269287
# Processing 5
# Time taken 1.5993380546569824
# Processing 6
# Time taken 1.5005910396575928
# Processing 7
# Time taken 0.29529643058776855
# Processing 8
# Time taken 1.2511653900146484
# Processing 9
# Time taken 0.8965868949890137
# Processing 10
# Time taken 1.821153163909912
# Processing 11
# Time taken 1.5683438777923584
# Processing 12
# Time taken 1.512573480606079
# Processing 13
# Time taken 1.0822186470031738
# Processing 14
# Time taken 2.29434871673584
# Processing 15
# Time taken 1.2475383281707764
# Processing 16
# Time taken 0.7138645648956299
# Processing 17
# Time taken 1.5414891242980957
# Processing 18
# Time taken 1.4130980968475342
# Processing 19
# Time taken 1.456848382949829
# Processing 20
# Time taken 1.1480307579040527
# Processing 21
# Time taken 1.6885275840759277
# Processing 22
# Time taken 0.4851841926574707
# Processing 23
# Time taken 1.1425092220306396
# Processing 24
# Time taken 1.5807178020477295
# Processing 25
# Time taken 0.9956710338592529
# Processing 26
# Time taken 1.5978970527648926
# Processing 27
# Time taken 0.8359284400939941
# Processing 28
# Time taken 0.48232150077819824
# Processing 29
# Time taken 1.6063575744628906
# Processing 30
# Time taken 1.7430460453033447
# Processing 31
# Time taken 1.4991679191589355
# Processing 32
# Time taken 1.547640323638916
# Processing 33
# Time taken 1.5689303874969482
# Processing 34
# Time taken 1.223562479019165
# Processing 35
# Time taken 1.782167673110962
# Processing 36
# Time taken 1.8592109680175781
# Processing 37
# Time taken 1.2298779487609863
# Processing 38
# Time taken 1.5756175518035889
# Processing 39
# Time taken 1.6545116901397705
# Processing 40
# Time taken 1.8315181732177734
# Processing 41
# Time taken 1.6913561820983887
# Processing 42
# Time taken 1.246262788772583
# Processing 43
# Time taken 1.4448699951171875
# Processing 44
# Time taken 1.595080852508545
# Processing 45
# Time taken 1.2819087505340576
# Processing 46
# Time taken 1.0516555309295654
# Processing 47
# Time taken 1.1767816543579102
# Processing 48
# Time taken 0.9296534061431885
# Processing 49
# Time taken 1.4853098392486572
# Processing 0
# Time taken 1.6863622665405273
# Processing 1
# Time taken 2.5381457805633545
# Processing 2
# Time taken 2.484698534011841
# Processing 3
# Time taken 2.6164309978485107
# Processing 4
# Time taken 2.0929722785949707
# Processing 5
# Time taken 2.194652557373047
# Processing 6
# Time taken 2.3652594089508057
# Processing 7
# Time taken 0.3722684383392334
# Processing 8
# Time taken 1.830698013305664
# Processing 9
# Time taken 1.202080488204956
# Processing 10
# Time taken 2.7631843090057373
# Processing 11
# Time taken 2.437065601348877
# Processing 12
# Time taken 2.3753485679626465
# Processing 13
# Time taken 1.4583086967468262
# Processing 14
# Time taken 4.720135927200317
# Processing 15
# Time taken 1.8598265647888184
# Processing 16
# Time taken 0.999542236328125
# Processing 17
# Time taken 2.4364700317382812
# Processing 18
# Time taken 2.263286590576172
# Processing 19
# Time taken 2.32450270652771
# Processing 20
# Time taken 1.6574997901916504
# Processing 21
# Time taken 2.6334786415100098
# Processing 22
# Time taken 0.7031865119934082
# Processing 23
# Time taken 1.7509636878967285
# Processing 24
# Time taken 2.3439016342163086
# Processing 25
# Time taken 1.5506064891815186
# Processing 26
# Time taken 2.5331315994262695
# Processing 27
# Time taken 1.2804808616638184
# Processing 28
# Time taken 0.6103165149688721
# Processing 29
# Time taken 2.607062578201294
# Processing 30
# Time taken 2.683826446533203
# Processing 31
# Time taken 2.6337687969207764
# Processing 32
# Time taken 2.300530433654785
# Processing 33
# Time taken 2.4588706493377686
# Processing 34
# Time taken 2.031975269317627
# Processing 35
# Time taken 2.7650768756866455
# Processing 36
# Time taken 2.8114266395568848
# Processing 37
# Time taken 1.9285244941711426
# Processing 38
# Time taken 2.4400644302368164
# Processing 39
# Time taken 2.4810478687286377
# Processing 40
# Time taken 2.8958795070648193
# Processing 41
# Time taken 2.6650149822235107
# Processing 42
# Time taken 1.7668955326080322
# Processing 43
# Time taken 2.290637969970703
# Processing 44
# Time taken 2.432344675064087
# Processing 45
# Time taken 1.9851174354553223
# Processing 46
# Time taken 1.7407457828521729
# Processing 47
# Time taken 1.6368417739868164
# Processing 48
# Time taken 1.3670248985290527
# Processing 49
# Time taken 2.303654432296753

# %%
import pandas as pd
import json
import torch
import time

ratios = [0.25, 0.5, 0.75]
# dataset_name_list = ['hotpotqa', 'narrative_qa', 'triviaqa', 'multifieldqa']
dataset_name = dataset_name_list[2]  #triviaqa
for i in ratios:
    try:
      df = pd.read_csv(f'{dataset_name}/summarize_{dataset_name}_{int(i * 100)}.csv')
      metrics = evaluate_trivia(df)
      with open(f'{dataset_name}_metrics_{int(i * 100)}.json', 'w') as f:
        json.dump(metrics, f)
    except Exception as e:
        print("Failed with error: ", e)
# Out:
# Processing 0
# Time taken 0.2795112133026123
# Processing 1
# Time taken 1.047398328781128
# Processing 2
# Time taken 0.6987898349761963
# Processing 3
# Time taken 1.1434462070465088
# Processing 4
# Time taken 0.7824344635009766
# Processing 5
# Time taken 0.7599151134490967
# Processing 6
# Time taken 0.5941810607910156
# Processing 7
# Time taken 0.30580615997314453
# Processing 8
# Time taken 0.4257078170776367
# Processing 9
# Time taken 0.6409378051757812
# Processing 10
# Time taken 1.0865490436553955
# Processing 11
# Time taken 0.6006135940551758
# Processing 12
# Time taken 0.3444385528564453
# Processing 13
# Time taken 0.8535211086273193
# Processing 14
# Time taken 0.3938422203063965
# Processing 15
# Time taken 0.46035265922546387
# Processing 16
# Time taken 0.898949384689331
# Processing 17
# Time taken 0.22241425514221191
# Processing 18
# Time taken 0.8796632289886475
# Processing 19
# Time taken 0.8445568084716797
# Processing 20
# Time taken 0.8147344589233398
# Processing 21
# Time taken 0.4385213851928711
# Processing 22
# Time taken 0.6235699653625488
# Processing 23
# Time taken 0.8633418083190918
# Processing 24
# Time taken 1.195185661315918
# Processing 25
# Time taken 0.808220386505127
# Processing 26
# Time taken 1.006035327911377
# Processing 27
# Time taken 0.45044684410095215
# Processing 28
# Time taken 0.23050808906555176
# Processing 29
# Time taken 0.7620468139648438
# Processing 30
# Time taken 0.7526960372924805
# Processing 31
# Time taken 0.25741052627563477
# Processing 32
# Time taken 0.9399247169494629
# Processing 33
# Time taken 0.5570275783538818
# Processing 34
# Time taken 0.9335591793060303
# Processing 35
# Time taken 1.2655727863311768
# Processing 36
# Time taken 0.17012357711791992
# Processing 37
# Time taken 1.2596333026885986
# Processing 38
# Time taken 1.0999188423156738
# Processing 39
# Time taken 0.8210427761077881
# Processing 40
# Time taken 0.5275919437408447
# Processing 41
# Time taken 0.4259755611419678
# Processing 42
# Time taken 0.4799180030822754
# Processing 43
# Time taken 0.6447460651397705
# Processing 44
# Time taken 0.7859101295471191
# Processing 45
# Time taken 0.5633180141448975
# Processing 46
# Time taken 0.5976545810699463
# Processing 47
# Time taken 0.9603979587554932
# Processing 48
# Time taken 0.8188009262084961
# Processing 49
# Time taken 0.6555964946746826
# Processing 0
# Time taken 0.5211241245269775
# Processing 1
# Time taken 1.8439888954162598
# Processing 2
# Time taken 1.270176649093628
# Processing 3
# Time taken 2.2306790351867676
# Processing 4
# Time taken 1.317594289779663
# Processing 5
# Time taken 1.215822696685791
# Processing 6
# Time taken 0.8704407215118408
# Processing 7
# Time taken 0.41263365745544434
# Processing 8
# Time taken 0.5716392993927002
# Processing 9
# Time taken 1.0599064826965332
# Processing 10
# Time taken 2.0990352630615234
# Processing 11
# Time taken 1.0459861755371094
# Processing 12
# Time taken 0.5387232303619385
# Processing 13
# Time taken 1.3815317153930664
# Processing 14
# Time taken 0.5486476421356201
# Processing 15
# Time taken 0.6596283912658691
# Processing 16
# Time taken 1.7125234603881836
# Processing 17
# Time taken 0.3180713653564453
# Processing 18
# Time taken 1.6179654598236084
# Processing 19
# Time taken 1.6377296447753906
# Processing 20
# Time taken 1.354491949081421
# Processing 21
# Time taken 0.5895309448242188
# Processing 22
# Time taken 0.988029956817627
# Processing 23
# Time taken 1.382634162902832
# Processing 24
# Time taken 2.0571494102478027
# Processing 25
# Time taken 1.3944063186645508
# Processing 26
# Time taken 1.8771803379058838
# Processing 27
# Time taken 0.6814689636230469
# Processing 28
# Time taken 0.31584835052490234
# Processing 29
# Time taken 1.3141875267028809
# Processing 30
# Time taken 1.4850704669952393
# Processing 31
# Time taken 0.3470780849456787
# Processing 32
# Time taken 1.6768882274627686
# Processing 33
# Time taken 0.8338773250579834
# Processing 34
# Time taken 1.5087497234344482
# Processing 35
# Time taken 2.370297431945801
# Processing 36
# Time taken 0.2181987762451172
# Processing 37
# Time taken 2.3095879554748535
# Processing 38
# Time taken 2.1305127143859863
# Processing 39
# Time taken 1.3047537803649902
# Processing 40
# Time taken 0.8758947849273682
# Processing 41
# Time taken 0.7601213455200195
# Processing 42
# Time taken 0.48566198348999023
# Processing 43
# Time taken 0.7037532329559326
# Processing 44
# Time taken 1.3560066223144531
# Processing 45
# Time taken 1.0934851169586182
# Processing 46
# Time taken 1.018775224685669
# Processing 47
# Time taken 1.6222546100616455
# Processing 48
# Time taken 1.4575939178466797
# Processing 49
# Time taken 1.183086633682251
# Processing 0
# Time taken 0.741008996963501
# Processing 1
# Time taken 2.778517246246338
# Processing 2
# Time taken 1.872981071472168
# Processing 3
# Time taken 3.556288003921509
# Processing 4
# Time taken 1.8403167724609375
# Processing 5
# Time taken 2.0042800903320312
# Processing 6
# Time taken 1.1942176818847656
# Processing 7
# Time taken 0.5396871566772461
# Processing 8
# Time taken 0.7701632976531982
# Processing 9
# Time taken 1.4466116428375244
# Processing 10
# Time taken 3.3241477012634277
# Processing 11
# Time taken 1.4754903316497803
# Processing 12
# Time taken 0.7305617332458496
# Processing 13
# Time taken 2.060412645339966
# Processing 14
# Time taken 0.7149882316589355
# Processing 15
# Time taken 0.8645663261413574
# Processing 16
# Time taken 2.6516287326812744
# Processing 17
# Time taken 0.41407251358032227
# Processing 18
# Time taken 2.622197389602661
# Processing 19
# Time taken 2.5670902729034424
# Processing 20
# Time taken 1.9977967739105225
# Processing 21
# Time taken 0.7665047645568848
# Processing 22
# Time taken 1.368314266204834
# Processing 23
# Time taken 1.961911678314209
# Processing 24
# Time taken 3.1991896629333496
# Processing 25
# Time taken 2.0698533058166504
# Processing 26
# Time taken 3.100229263305664
# Processing 27
# Time taken 0.8188393115997314
# Processing 28
# Time taken 0.6005542278289795
# Processing 29
# Time taken 1.9586563110351562
# Processing 30
# Time taken 1.8036630153656006
# Processing 31
# Time taken 0.4591395854949951
# Processing 32
# Time taken 2.520007610321045
# Processing 33
# Time taken 1.0712676048278809
# Processing 34
# Time taken 2.1050992012023926
# Processing 35
# Time taken 3.691969633102417
# Processing 36
# Time taken 0.2682645320892334
# Processing 37
# Time taken 3.709839105606079
# Processing 38
# Time taken 3.235629081726074
# Processing 39
# Time taken 1.8068640232086182
# Processing 40
# Time taken 1.1983318328857422
# Processing 41
# Time taken 1.1651480197906494
# Processing 42
# Time taken 0.6200809478759766
# Processing 43
# Time taken 1.2165820598602295
# Processing 44
# Time taken 1.9676826000213623
# Processing 45
# Time taken 1.5778613090515137
# Processing 46
# Time taken 1.3138628005981445
# Processing 47
# Time taken 2.4030697345733643
# Processing 48
# Time taken 2.2391984462738037
# Processing 49
# Time taken 1.8090441226959229

# %%
import pandas as pd
import json
import torch
import time

ratios = [0.25, 0.5, 0.75]
# dataset_name_list = ['hotpotqa', 'narrative_qa', 'triviaqa', 'multifieldqa']
dataset_name = dataset_name_list[3]  #narrative_qa
for i in ratios:
    try:
      df = pd.read_csv(f'{dataset_name}/summarize_{dataset_name}_{int(i * 100)}.csv')
      metrics = evaluate_narrative(df)
      with open(f'{dataset_name}_metrics_{int(i * 100)}.json', 'w') as f:
        json.dump(metrics, f)
    except Exception as e:
        print("Failed with error: ", e)
# Out:
# Processing 0
# Time taken 1.6991956233978271
# Processing 1
# Time taken 1.9323482513427734
# Processing 2
# Time taken 0.5165257453918457
# Processing 3
# Time taken 0.6742467880249023
# Processing 4
# Time taken 2.332346200942993
# Processing 5
# Time taken 0.7260270118713379
# Processing 6
# Time taken 1.5438194274902344
# Processing 7
# Time taken 1.9648559093475342
# Processing 8
# Time taken 1.3404452800750732
# Processing 9
# Time taken 1.0115773677825928
# Processing 10
# Time taken 2.529669761657715
# Processing 11
# Time taken 1.0242137908935547
# Processing 12
# Time taken 5.895442008972168
# Processing 13
# Time taken 0.5545692443847656
# Processing 14
# Time taken 0.6025290489196777
# Processing 15
# Time taken 2.117722272872925
# Processing 16
# Time taken 1.231825590133667
# Processing 17
# Time taken 2.6803884506225586
# Processing 18
# Time taken 1.687713623046875
# Processing 19
# Time taken 1.7755730152130127
# Processing 20
# Time taken 2.7800498008728027
# Processing 21
# Time taken 1.9235246181488037
# Processing 22
# Time taken 2.991563081741333
# Processing 23
# Time taken 0.44313907623291016
# Processing 24
# Time taken 1.5865321159362793
# Processing 25
# Time taken 1.4470219612121582
# Processing 26
# Time taken 0.7245488166809082
# Processing 27
# Time taken 2.9123966693878174
# Processing 28
# Time taken 1.9688389301300049
# Processing 29
# Time taken 2.0187602043151855
# Processing 30
# Time taken 0.8778789043426514
# Processing 31
# Time taken 2.0191292762756348
# Processing 32
# Time taken 1.213390588760376
# Processing 33
# Time taken 1.9273443222045898
# Processing 34
# Time taken 53.127978801727295
# Processing 35
# Time taken 1.928400993347168
# Processing 36
# Time taken 2.7337160110473633
# Processing 37
# Time taken 1.031909704208374
# Processing 38
# Time taken 2.231184244155884
# Processing 39
# Time taken 2.001479387283325
# Processing 40
# Time taken 1.883493185043335
# Processing 41
# Time taken 1.2120797634124756
# Processing 42
# Time taken 0.7502837181091309
# Processing 43
# Time taken 1.3818306922912598
# Processing 44
# Time taken 1.1848182678222656
# Processing 45
# Time taken 0.8824059963226318
# Processing 46
# Time taken 1.720085859298706
# Processing 47
# Time taken 1.8929510116577148
# Processing 48
# Time taken 0.917994499206543
# Processing 49
# Time taken 0.9314181804656982
# Processing 0
# Time taken 3.2890074253082275
# Processing 1
# Time taken 3.5078470706939697
# Processing 2
# Time taken 0.9103169441223145
# Processing 3
# Time taken 1.1065585613250732
# Processing 4
# Time taken 4.446751117706299
# Processing 5
# Time taken 1.3354928493499756
# Processing 6
# Time taken 2.5211853981018066
# Processing 7
# Time taken 5.20180606842041
# Processing 8
# Time taken 2.859691619873047
# Processing 9
# Time taken 1.4699182510375977
# Processing 10
# Time taken 5.36384391784668
# Processing 11
# Time taken 1.692166805267334
# Processing 12
# Time taken 29.25678062438965
# Processing 13
# Time taken 1.5463004112243652
# Processing 14
# Time taken 1.1256999969482422
# Processing 15
# Time taken 4.803779125213623
# Processing 16
# Time taken 2.3073670864105225
# Processing 17
# Time taken 4.513455152511597
# Processing 18
# Time taken 2.743255853652954
# Processing 19
# Time taken 0.9580075740814209
# Processing 20
# Time taken 1.4105067253112793
# Processing 21
# Time taken 4.182179927825928
# Processing 22
# Time taken 6.481113910675049
# Processing 23
# Time taken 0.8697845935821533
# Processing 24
# Time taken 3.1917707920074463
# Processing 25
# Time taken 3.2831408977508545
# Processing 26
# Time taken 1.2893760204315186
# Processing 27
# Time taken 7.504756212234497
# Processing 28
# Time taken 3.829293727874756
# Processing 29
# Time taken 3.1384739875793457
# Processing 30
# Time taken 1.795170545578003
# Processing 31
# Time taken 4.360796213150024
# Processing 32
# Time taken 2.561816692352295
# Processing 33
# Time taken 3.2624781131744385
# Processing 34
# Time taken 1.2453639507293701
# Processing 35
# Time taken 4.053520202636719
# Processing 36
# Time taken 6.403836011886597
# Processing 37
# Time taken 1.2855560779571533
# Processing 38
# Time taken 4.405266284942627
# Processing 39
# Time taken 3.9429004192352295
# Processing 40
# Time taken 4.523139476776123
# Processing 41
# Time taken 2.778284788131714
# Processing 42
# Time taken 0.9585514068603516
# Processing 43
# Time taken 2.8754210472106934
# Processing 44
# Time taken 1.342801570892334
# Processing 45
# Time taken 1.5796394348144531
# Processing 46
# Time taken 4.125096559524536
# Processing 47
# Time taken 5.4113709926605225
# Processing 48
# Time taken 1.8226542472839355
# Processing 49
# Time taken 1.9292254447937012
# Processing 0
# Time taken 5.33225679397583
# Processing 1
# Time taken 5.613414764404297
# Processing 2
# Time taken 1.308821201324463
# Processing 3
# Time taken 1.5435535907745361
# Processing 4
# Time taken 7.149456977844238
# Processing 5
# Time taken 1.9777722358703613
# Processing 6
# Time taken 4.208894729614258
# Processing 7
# Failed with error:  Input length of input_ids is 33025, but `max_length` is set to 32768. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Processing 8
# Time taken 4.8631250858306885
# Processing 9
# Time taken 1.974912166595459
# Processing 10
# Time taken 7.955327987670898
# Processing 11
# Time taken 2.893444538116455
# Processing 12
# Time taken 15.344052791595459
# Processing 13
# Time taken 2.1234750747680664
# Processing 14
# Time taken 1.787903070449829
# Processing 15
# Failed with error:  Input length of input_ids is 33023, but `max_length` is set to 32768. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Processing 16
# Time taken 3.256439447402954
# Processing 17
# Time taken 8.095499515533447
# Processing 18
# Time taken 5.2471020221710205
# Processing 19
# Time taken 2.8559770584106445
# Processing 20
# Time taken 2.0958423614501953
# Processing 21
# Time taken 7.116198778152466
# Processing 22
# Failed with error:  Input length of input_ids is 42107, but `max_length` is set to 32768. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Processing 23
# Time taken 1.2156918048858643
# Processing 24
# Time taken 5.279801845550537
# Processing 25
# Time taken 5.185079574584961
# Processing 26
# Time taken 1.48054838180542
# Processing 27
# Failed with error:  Input length of input_ids is 42903, but `max_length` is set to 32768. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Processing 28
# Time taken 5.397034645080566
# Processing 29
# Time taken 5.010165691375732
# Processing 30
# Time taken 3.4006805419921875
# Processing 31
# Time taken 5.410613536834717
# Processing 32
# Time taken 4.26215124130249
# Processing 33
# Time taken 5.498271703720093
# Processing 34
# Time taken 1.9839506149291992
# Processing 35
# Time taken 6.467625379562378
# Processing 36
# Failed with error:  Input length of input_ids is 42105, but `max_length` is set to 32768. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Processing 37
# Time taken 2.136948823928833
# Processing 38
# Failed with error:  Input length of input_ids is 33023, but `max_length` is set to 32768. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Processing 39
# Time taken 6.85628867149353
# Processing 40
# Failed with error:  Input length of input_ids is 33021, but `max_length` is set to 32768. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Processing 41
# Time taken 4.5051891803741455
# Processing 42
# Time taken 1.2104716300964355
# Processing 43
# Time taken 4.6190025806427
# Processing 44
# Time taken 2.056506395339966
# Processing 45
# Time taken 2.599790096282959
# Processing 46
# Time taken 7.147880792617798
# Processing 47
# Time taken 6.107234954833984
# Processing 48
# Time taken 3.013583183288574
# Processing 49
# Time taken 2.7880825996398926
